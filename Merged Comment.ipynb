# %%
import pandas as pd

df1 = pd.read_csv('hasil1.csv')
df2 = pd.read_csv('hasil2.csv')
df3 = pd.read_csv('hasil3.csv')
df4 = pd.read_csv('hasil4.csv')

merged_df = pd.concat([df1, df2, df3, df4], axis=0, ignore_index=True)

merged_df.to_csv('merge_hasil.csv', index=False)

# %%
df = merged_df['Comment']
df.to_csv('comment_hasil.csv', index=False)
df
# Out:
# 0       jika anggaran di total mngenai pembangunan jak...
# 1                                       Alhamdulillah....
# 2       Dibangun oleh beliau, dan dinikmati oleh gener...
# 3       Semua akan di nikmati oleh2 cucu kita .di jama...
# 4       Pak jokowi jangan hanya pembangunan nya saja ....
#                               ...
# 9396      BILANG AJA TAKUT BILA INDONESIA TERUS BERTUMBUH
# 9397                                 Utangnya bertumbuh?😑
# 9398    @@bambutumpul NEGARA MANA YANG TIDAK PUNYA HUT...
# 9399    Mereka cuma analis neng...logis juga sih pe \n...
# 9400    Jangan cuma bisa kritik … kalau tdk tau apa al...
# Name: Comment, Length: 9401, dtype: object
