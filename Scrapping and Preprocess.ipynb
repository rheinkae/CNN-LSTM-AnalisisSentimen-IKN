# %%
# -*- coding: utf-8 -*-
#!/bin/env python3
# Telegram Group: http://t.me/cyberclans
# Please give me credits if you use any codes from here.

import os, sys
import configparser
re="\033[1;31m"
gr="\033[1;32m"
cy="\033[1;36m"
def banner():
	os.system('clear')
	print(f"""
	{re}╔═╗{cy}┌─┐┌┬┐┬ ┬┌─┐
	{re}╚═╗{cy}├┤  │ │ │├─┘
	{re}╚═╝{cy}└─┘ ┴ └─┘┴   v1.0
	""")
banner()
print(gr+"[+] Installing requierments ...")
os.system('python -m pip install pandas')
os.system('pip install apiclient')
os.system('pip install --upgrade google-api-python-client')
banner()
os.system("touch config.data")
cpass = configparser.RawConfigParser()
cpass.add_section('cred')
xid = input(gr+"[+] Enter Api Key : "+re)
cpass.set('cred', 'id', xid)
xhash = input(gr+"[+] Enter Video ID : "+re)
cpass.set('cred', 'hash', xhash)
setup = open('config.data', 'w')
cpass.write(setup)
setup.close()
print(gr+"[+] Setup complete!")
print(gr+"[+] Now you can run YouTube Scraper!")
print(gr+"[+] Make sure to read README.md before using this tool.")
print(gr+"[+] https://github.com/palahsu/YouTubeScraper/blob/master/README.md")
print("\033[92m[+] Telegram Group: \033[96mhttp://t.me/cyberclans\033[0m")
# Out:
# 	╔═╗┌─┐┌┬┐┬ ┬┌─┐
# 	╚═╗├┤  │ │ │├─┘
# 	╚═╝└─┘ ┴ └─┘┴   v1.0
#
# [+] Installing requierments ...
#
# 	╔═╗┌─┐┌┬┐┬ ┬┌─┐
# 	╚═╗├┤  │ │ │├─┘
# 	╚═╝└─┘ ┴ └─┘┴   v1.0
# [+] Enter Api Key :  AIzaSyBnNdhvCHIg_S9gZkGOgu9o_JK4JWBPuuQ
# [+] Enter Video ID :  utDcbTTgk9Y
# [+] Setup complete!
# [+] Now you can run YouTube Scraper!
# [+] Make sure to read README.md before using this tool.
# [+] https://github.com/palahsu/YouTubeScraper/blob/master/README.md
# [+] Telegram Group: http://t.me/cyberclans

# %%
# -*- coding: utf-8 -*-
#!/bin/env python3
# Telegram Group: http://t.me/cyberclans
# Please give me credits if you use any codes from here.
import apiclient.discovery
from apiclient.discovery import build
import pandas as pd

# Put api key with your own.
Api_Key = "AIzaSyBnNdhvCHIg_S9gZkGOgu9o_JK4JWBPuuQ"

youtube = build('youtube', 'v3', developerKey=Api_Key)

# Put Any YouTube video ID.
ID = "utDcbTTgk9Y"

List = [['Name', 'Comment','Likes', 'time', 'Reply Count']]

def scrape_all_with_replies():
    data = youtube.commentThreads().list(part='snippet', videoId=ID, maxResults='100', textFormat="plainText").execute()

    for i in data["items"]:

        name = i["snippet"]['topLevelComment']["snippet"]["authorDisplayName"]
        comment = i["snippet"]['topLevelComment']["snippet"]["textDisplay"]
        likes = i["snippet"]['topLevelComment']["snippet"]['likeCount']
        published_at = i["snippet"]['topLevelComment']["snippet"]['publishedAt'] 
        replies = i["snippet"]['totalReplyCount']

        List.append([name, comment, likes, published_at, replies])

        TotalReplyCount = i["snippet"]['totalReplyCount']

        if TotalReplyCount > 0:

            parent = i["snippet"]['topLevelComment']["id"]

            data2 = youtube.comments().list(part='snippet', maxResults='100', parentId=parent,
                                            textFormat="plainText").execute()

            for i in data2["items"]:
                name = i["snippet"]["authorDisplayName"]
                comment = i["snippet"]["textDisplay"]
                likes = i["snippet"]['likeCount']
                published_at = i["snippet"]['publishedAt']
                replies = ""

                List.append([name, comment, published_at, likes, replies])

    while ("nextPageToken" in data):

        data = youtube.commentThreads().list(part='snippet', videoId=ID, pageToken=data["nextPageToken"],
                                             maxResults='100', textFormat="plainText").execute()

        for i in data["items"]:
            name = i["snippet"]['topLevelComment']["snippet"]["authorDisplayName"]
            comment = i["snippet"]['topLevelComment']["snippet"]["textDisplay"]
            likes = i["snippet"]['topLevelComment']["snippet"]['likeCount']
            published_at = i["snippet"]['topLevelComment']["snippet"]['publishedAt']
            replies = i["snippet"]['totalReplyCount']


            List.append([name, comment, likes, published_at, replies])

            TotalReplyCount = i["snippet"]['totalReplyCount']

            if TotalReplyCount > 0:

                parent = i["snippet"]['topLevelComment']["id"]

                data2 = youtube.comments().list(part='snippet', maxResults='100', parentId=parent,
                                                textFormat="plainText").execute()

                for i in data2["items"]:
                    name = i["snippet"]["authorDisplayName"]
                    comment = i["snippet"]["textDisplay"]
                    likes = i["snippet"]['likeCount']
                    published_at = i["snippet"]['publishedAt']
                    replies = ''

                    List.append([name, comment, likes, published_at, replies])

    df = pd.DataFrame({'Name': [i[0] for i in List], 'Comment': [i[1] for i in List], 'Likes': [i[2] for i in List], 'Time': [i[3] for i in List],
                       'Reply Count': [i[4] for i in List]})

    df.to_csv('hasil5.csv', index=False, header=False)

    return "Successful! Check the CSV file that you have just created."


scrape_all_with_replies()
# Out:
# 'Successful! Check the CSV file that you have just created.'

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('hasil1.csv')
df
# Out:
#                     Name                                            Comment  \
# 0        @bumdesjaya4542  Ihh liat proges IKN kubu sebelah makin kejang ...
# 1     @sietamofficial539                  Ikn apa masih nkri klo udah jadi?
# 2             @czachanel  perbanyak pabrik dan lowongan kerja di ikn dij...
# 3             @AlelJapan  Semoga Tuhan melindungi warga Kalimantan akan ...
# 4       @sastramanik8032                                 Pasti sejuk disana
# ...                  ...                                                ...
# 1664    @abdulmunibb4896  ANIS SIAP AKAN MENGHENTIKAN PEMBANGUNAN IKN....!!
# 1665          @bobon3233  @@abdulmunibb4896 di mana mana ni orang sepam ...
# 1666       @diaryeel8902                                       Abroad Debt?
# 1667    @Purnabakrie2025              Semoga IKN lancar dan membawa barokah
# 1668        @fotodekacom                       ninggalin jejak pertamax....
#
#      Likes                  time  Reply Count
# ...

# %%
jumlahBaris = df.count()
print("jumlah baris: ", jumlahBaris)
#melihat skema dari dataframe kita
df
# Out:
# jumlah baris:  Name           1669
# Comment        1669
# Likes          1669
# time           1669
# Reply Count    1055
# dtype: int64
#                     Name                                            Comment  \
# 0        @bumdesjaya4542  Ihh liat proges IKN kubu sebelah makin kejang ...
# 1     @sietamofficial539                  Ikn apa masih nkri klo udah jadi?
# 2             @czachanel  perbanyak pabrik dan lowongan kerja di ikn dij...
# 3             @AlelJapan  Semoga Tuhan melindungi warga Kalimantan akan ...
# 4       @sastramanik8032                                 Pasti sejuk disana
# ...                  ...                                                ...
# 1664    @abdulmunibb4896  ANIS SIAP AKAN MENGHENTIKAN PEMBANGUNAN IKN....!!
# 1665          @bobon3233  @@abdulmunibb4896 di mana mana ni orang sepam ...
# 1666       @diaryeel8902                                       Abroad Debt?
# ...

# %%
df_no_null = df.dropna()

# Menampilkan DataFrame hasil
jumlahBaris = df_no_null.shape[0]
print("jumlah baris: ", jumlahBaris)
print(df_no_null.head(3))  # Menampilkan 3 baris pertama DataFrame
# Out:
# jumlah baris:  1055
#                  Name                                            Comment  \
# 0     @bumdesjaya4542  Ihh liat proges IKN kubu sebelah makin kejang ...
# 1  @sietamofficial539                  Ikn apa masih nkri klo udah jadi?
# 2          @czachanel  perbanyak pabrik dan lowongan kerja di ikn dij...
#
#   Likes                  time  Reply Count
# 0     0  2024-03-20T01:52:18Z          0.0
# 1     0  2024-03-18T12:15:56Z          0.0
# 2     0  2024-03-16T01:33:19Z          0.0

# %%
import re
import pandas as pd

# Filter komentar yang tidak mengandung tahun 2020-2023
tahun_dihapus = '2018|2019|2020|2021|2022|2023'
df_filtered = df_no_null[~df_no_null['time'].str.contains(tahun_dihapus, regex=True)]

# Menampilkan jumlah baris setelah penghapusan
jumlahBarisSetelahHapus = df_filtered.shape[0]
print("Jumlah baris setelah menghapus tahun 2018-2023:", jumlahBarisSetelahHapus)

# Menampilkan DataFrame yang telah difilter
print(df_filtered)

# Simpan DataFrame ke dalam file CSV
df_filtered.to_csv('filtered_comments.csv', index=False)
# Out:
# Jumlah baris setelah menghapus tahun 2018-2023: 284
#                     Name                                            Comment
# 1722         Sogel Bogel  Ini kalau aku Lihat. Ada Mainan Suami dan Oran...  \
# 1723       Antoni Darwin       Itu hukuman sosial yg pantas kamu dpt kan...
# 1724       Antoni Darwin  Biadabbbbbb... 7 turunan jesica perbuatan mu a...
# 1725               jey K  jesica ga mau nyobain krn kopinya strong bange...
# 1726       Nurvia Dinata  dr mirna datang karyawan bolak balik berapa ka...
# ...                  ...                                                ...
# 2571        Ika Kristina  liat waktu semua orang coba mndkt mirna jesika...
# 2573           Abzy Sifa                     ini yg bikin semua penasaran😁😁
# 2574          Aŕąmbõə 85             tega sekli klw mmg benar plkux jessika
# 2575  MAIN BARENG EMILIE                                                 :(
# 2576               SANNI                                                 :(
#
# ...

# %% [markdown]
# ## PRE-PROCESSING ##

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df=pd.read_csv('filtered_comments.csv')
df
# Out:
#                               Name
# 0                     wieseka Fdgg  \
# 1                           Lthree
# 2                      سيلا رستينا
# 3                       wina zanon
# 4                      Mawar Mawar
# 5             Nour halimah Abdulah
# 6                    Lets Playeah!
# 7                 Mbok LeaGried666
# 8                 Mbok LeaGried666
# 9                 Mbok LeaGried666
# 10                    seputar info
# 11         Nikeisha Nava Mischella
# 12                    beby seftian
# 13  Sri lestarie.lestarie Lestarie
# 14                     Fendi Antas
#
#                                               Comment  Likes
# 0   lupa tidak ingat tapi pas di rayu sma pak poli...     32  \
# 1   udah stress itu jessica,seluruh indonesia juga...     61
# 2                           hebat bgt bohongy jessica     13
# 3   semuanya tdk ingat/lupa apakah dia lupa ingata...     23
# 4   aneh smuanya ngga ingat,pdhal dia sendrian d s...     63
# ...
